# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("youtube.csv")

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df = df.replace(np.nan, "unknown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 995 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  995 non-null    object
#  8   Abbreviation                             995 non-null    object
#  9   channel_type                             995 non-null    object
# ...

# %%
print(df.duplicated().any())
# Out:
# False

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254
# min      1.00000  1.230000e+07  0.000000e+00       0.000000
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000
#
#        lowest_monthly_earnings  highest_monthly_earnings  \
# count               995.000000              9.950000e+02
# mean              36886.148281              5.898078e+05
# std               71858.724092              1.148622e+06
# min                   0.000000              0.000000e+00
# 25%                2700.000000              4.350000e+04
# 50%               13300.000000              2.127000e+05
# ...

# %%
Count_Unique_category = df["category"].nunique()
print("Total unique Category : ",Count_Unique_category)
unique_category = df["category"].unique()
print("Categories:-")
for i in unique_category:
    print(i)
# Out:
# Total unique Category :  19
# Categories:-
# Music
# Film & Animation
# Entertainment
# Education
# Shows
# unknown
# People & Blogs
# Gaming
# Sports
# Howto & Style
# News & Politics
# Comedy
# Trailers
# Nonprofits & Activism
# Science & Technology
# Movies
# Pets & Animals
# Autos & Vehicles
# Travel & Events

# %%
Count_Unique_country = df["Country"].nunique()
print("Total unique Country : ",Count_Unique_category)
unique_country = df["Country"].unique()
print("Countries:-")
for i in unique_country:
    print(i)
# Out:
# Total unique Country :  19
# Countries:-
# India
# United States
# unknown
# Japan
# Russia
# South Korea
# United Kingdom
# Canada
# Brazil
# Argentina
# Chile
# Cuba
# El Salvador
# Pakistan
# Philippines
# Thailand
# Colombia
# Barbados
# Mexico
# United Arab Emirates
# Spain
# Saudi Arabia
# Indonesia
# Turkey
# Venezuela
# Kuwait
# Jordan
# Netherlands
# Singapore
# Australia
# Italy
# Germany
# France
# Sweden
# Afghanistan
# Ukraine
# Latvia
# Switzerland
# Vietnam
# Malaysia
# China
# Iraq
# Egypt
# Andorra
# Ecuador
# Morocco
# Peru
# Bangladesh
# Finland
# Samoa

# %%
Channels_in_country = df.groupby("Country")['Youtuber'].count().nlargest(5) 
plt.figure(figsize=(12,8))
bars = Channels_in_country.plot(kind="bar",color = 'green')
plt.xlabel("Countries")
plt.ylabel("Count of Channels")
plt.title("top 5 countries by total channels")
plt.xticks(rotation=45, ha='right')

for i,j in enumerate(Channels_in_country):
           plt.text(i,j, str(int(j)), ha='center', va="bottom", fontsize=8)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
uploads_by_category = df.groupby('category')['uploads'].sum().reset_index()
top5=uploads_by_category.nlargest(5,'uploads')
plt.figure(figsize=(12, 8))
plot = plt.plot(top5['category'], top5['uploads'])
plt.plot(top5['category'], top5['uploads'],color = 'yellow')
plt.xlabel('category')
plt.ylabel('uploads')
plt.title('Top 5 Category by Total uploads')
plt.show()

# %%
Count_of_channel = df['channel_type'].value_counts()
labels = Count_of_channel.index
counts = Count_of_channel.values
plt.figure(figsize=(12,8))
plt.plot(labels,counts,color='blue',marker='o')
plt.xlabel("Channel Type")
plt.ylabel("Count of channel")
plt.title("Count of Channel by Channel_Type")
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
value_counts = df.groupby('created_year')['highest_yearly_earnings'].sum()
top_5_values = value_counts.sort_values(ascending=False).head(5)
labels=top_5_values.index
value=(top_5_values.values).astype(int)
plt.pie(value,labels=value)
legend_labels = [f'{int(label)}' for label in labels]
plt.legend(legend_labels,loc='center right',title="Year")
plt.title("Top 5 Highest_Yearly_Earnings by Years")
# Out:
# Text(0.5, 1.0, 'Top 5 Highest_Yearly_Earnings by Years')
